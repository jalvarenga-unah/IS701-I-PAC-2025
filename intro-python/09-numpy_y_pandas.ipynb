# %% [markdown]
# ## Uso de Numpy

# %%
import numpy as np

# %%
listado_temperaturas = np.random.randint( -5, 35, size=(7,24) )

# %%
listado_temperaturas
# Out:
# array([[25,  4, 14, 18, 27, -1, 32, 22, 23, -3,  9, -3, 31, 22,  8, 34,
#         21,  0, 13, 25, 26, 32, 23, 26],
#        [15, 10, -2, -4,  5, 30, 25, 14, -5, 11, 25, 15,  7, 29, 16,  0,
#         15, 34,  0, 23, 17, 23, 21, 34],
#        [28,  4, 20, 12,  3, 19, 18, 11, 20, -5, 31, -4,  5, 23, 22, 14,
#         -4, 12, -3, 20, 30, 30, 22, 22],
#        [ 6, 13, 16,  2, 34, 21, 11, 23, 20, 16, -1, 29, 28,  9, 31, 30,
#         13, 17, 17, 31, 31, -3,  2, 24],
#        [27,  3,  9, 32, 13,  0, 14, 22, 21, 25, -3, 15, 31, 17, 29, 31,
#          0, 12, 22, 11, 20, 30, 23,  1],
#        [32, 13, 27, 22,  7, -3, 29, 24, 24, 32,  5,  8, -4, 34, 31,  3,
#          5, 10, 34, 23,  1, 24, 13, 27],
#        [21,  6,  6, 34, 31,  4, 28, 22, -3,  3, 29, 26,  9, 30, -2,  6,
#         26, 26,  4, 23,  9, -4,  4, 14]])

# %%
#temperaturas bajo cero
listado_temperaturas[ listado_temperaturas < 0 ]
# Out:
# array([-1, -3, -3, -2, -4, -5, -5, -4, -4, -3, -1, -3, -3, -3, -4, -3, -2,
#        -4])

# %%
# la temperatura mas alta de un dia

dia = listado_temperaturas[3 , :].max()

dia
# Out:
# 16

# %% [markdown]
# ## Uso de Pandas

# %%
# Para instalar: !pip install pandas
import pandas as pd

# %%
personas = {
    'nombre': [ 'Juan', 'Pedro', 'Maria' , None],
    'edad': [ 30, 20, 10, 40 ]
}

# Para crear un DataFrame
df = pd.DataFrame(personas)

df
# Out:
#   nombre  edad
# 0   Juan    30
# 1  Pedro    20
# 2  Maria    10
# 3   None    40

# %%
players = pd.read_csv('./data.csv')
players.shape
# Out:
# (1216, 7)

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216 entries, 0 to 1215
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Teams            1216 non-null   object
#  1   Seasons          1216 non-null   object
#  2   Players          1216 non-null   object
#  3   Matches          1216 non-null   int64
#  4   Goals            1216 non-null   int64
#  5   Assists          1216 non-null   int64
#  6   Seasons Ratings  1216 non-null   float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 66.6+ KB

# %%
players.head()
# Out:
#         Teams    Seasons       Players  Matches  Goals  Assists  \
# 0  InterMiami       2024  Lionel Messi       15     14       11
# 1  InterMiami       2023  Lionel Messi       14     11        5
# 2         PSG  2022/2023  Lionel Messi       41     21       20
# 3         PSG  2021/2022  Lionel Messi       34     11       14
# 4   Barcelona  2020/2021  Lionel Messi       47     38       12
#
#    Seasons Ratings
# 0              8.5
# 1              8.0
# 2              8.1
# 3              7.9
# 4              8.4

# %%
# players[ ['Players','Goals'] ]

sentencia = players['Goals'] > 30

players.loc[  sentencia , ['Players','Goals']]
# Out:
#                  Players  Goals
# 4           Lionel Messi     38
# 5           Lionel Messi     31
# 6           Lionel Messi     51
# 7           Lionel Messi     45
# 8           Lionel Messi     54
# 9      Cristiano Ronaldo     50
# 14     Cristiano Ronaldo     36
# 16     Cristiano Ronaldo     42
# 17     Cristiano Ronaldo     51
# 26                Neymar     31
# 27         Kylian Mbappe     44
# 28         Kylian Mbappe     41
# 29         Kylian Mbappe     39
# 30         Kylian Mbappe     42
# 32         Kylian Mbappe     39
# 38         Mohamed Salah     31
# 39         Mohamed Salah     31
# 42         Mohamed Salah     44
# 46         Kamir Benzema     31
# 47         Kamir Benzema     44
# 80     Antoine Griezmann     32
# 90            Harry Kane     44
# 91            Harry Kane     32
# 93            Harry Kane     33
# 96            Harry Kane     41
# 97            Harry Kane     35
# 107        Thomas Muller     32
# 109   Robert Lewandowski     33
# ...

# %%
sentencia = players['Goals'] > 30

# players.loc[  sentencia , ['Players','Goals']].groupby('Players').mean()
players.loc[  sentencia , ['Players','Goals']].groupby('Players').mean().sort_values('Goals', ascending=False)
# Out:
#                         Goals
# Players
# Cristiano Ronaldo   44.750000
# Robert Lewandowski  44.000000
# Lionel Messi        43.800000
# Erling Haaland      43.666667
# Kylian Mbappe       41.000000
# Kamir Benzema       37.500000
# Harry Kane          37.000000
# Mohamed Salah       35.333333
# Christopher Nkunku  35.000000
# Timo Werner         34.000000
# Romelu Lukaku       34.000000
# Ivan Toney          33.000000
# Thomas Muller       32.000000
# Antoine Griezmann   32.000000
# Raheem Sterling     31.000000
# Neymar              31.000000
# Bruno Fernandes     31.000000
# Victor Osimhen      31.000000

# %%
# players.columns # Me devuelve las columnas del DataFrame
# players.isna().value_counts()
# players = players.dropna() # eliminar los registros que contengan nulos
players.dropna(inplace=True) # eliminar los registros que contengan nulos
# Out:
# Teams  Seasons  Players  Matches  Goals  Assists  Seasons Ratings
# False  False    False    False    False  False    False              1216
# Name: count, dtype: int64

# %%
data_limpia = players.drop(['Teams','Players'], axis=1)
data_limpia
# Out:
#         Seasons  Matches  Goals  Assists  Seasons Ratings
# 0          2024       15     14       11              8.5
# 1          2023       14     11        5              8.0
# 2     2022/2023       41     21       20              8.1
# 3     2021/2022       34     11       14              7.9
# 4     2020/2021       47     38       12              8.4
# ...         ...      ...    ...      ...              ...
# 1211  2020/2021       43     13       10              7.1
# 1212  2019/2020       45     13       13              7.1
# 1213  2018/2019       41     14        2              6.7
# 1214  2017/2018       43     14        6              7.0
# 1215  2016/2017       43      4        8              6.6
#
# [1216 rows x 5 columns]

# %%
# TODO: tratar la info, para evular valores
data_limpia.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-915d61b80575> in <cell line: 0>()
# ----> 1 data_limpia.corr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...
